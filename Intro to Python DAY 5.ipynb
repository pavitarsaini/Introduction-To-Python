# %% [markdown]
# # **An introduction to Python**
# ## Session 5

# %% [markdown]
# ## What are we learning today?
#
# - Review
# - First Program

# %% [markdown]
# # **REVIEW**

# %% [markdown]
# ## Looping

# %% [markdown]
# ## While
# The first type of loop is the `while` loop.
# With the `while` loop we can execute a set of statements as long as a condition is true.

# %%
number = 1

while number <= 10 :
  print(number)
  number += 1
print('Done!')

# %% [markdown]
# ### Exercise 5.1
# print all even numbers up to 20

# %% [markdown]
# ## If
# Decision making is required when we want to execute a code only if a certain condition is satisfied.
#
# The `if` statement is used in Python for decision making.

# %%
text = input('Number? ')
number = int(text)

if number % 2 == 0 :
    print('Even number')
else :
    print('Odd number')

print('That was fun!')

# %% [markdown]
# ### Exercise 5.2
#
#
#
# 1.   input and store a number
# 2.   if number is under 10 print `under`
# 3.   if number is over 10 print `over`

# %% [markdown]
# ## Input validation
# An important step is “input validation”, where we check that the input makes sense.

# %%
text = input('Number? ')
number = float(text)

if number < 0.0:
  print('Number must be positive!')
exit()

# %% [markdown]
# ## “Chained” tests
# The input validation phase comes straight after the input itself.

# %%
text = input('Number?␣')
number = int(text)

if number == 0:
  print('Number cannot be zero!')
  exit()

elif number < 0:
  print('Number must be positive!')
elif number >= 1:
  print('Got it!')
else:
  print('Number not valid!')

# %% [markdown]
# # **Nesting**
# Nesting allows for powerful, yet simple programming. It reduces the amount of code needed, while making it simple for a programmer to debug and edit.

# %%
counter = 0
while counter <= 10:
  if counter == 5:
    print("Hey I am 5")
  else:
    print(counter)
  counter += 1

# %% [markdown]
# ## Exercise 5.3
# Print all odd numbers using an if statment in a while loop.
# `HINT: When an odd number is divided by 2, the remainder is 1`

# %% [markdown]
# # Putting it all together
# To put things together we will make a mock banking program

# %% [markdown]
# **Menu**
# ```
#     --------------------------------------
#     Python Bank
#     --------------------------------------
#     A. Check Balance
#     B. Deposit
#     C. Withdraw
#     E. Exit
#     --------------------------------------
#     Select an option: {User input}
# ```

# %% [markdown]
# **Options**
# ```
#     Select an option: A
#     Your balance is: {Balance}
#
#     Select an option: B
#     Enter amount of deposit: {User input}
#
#     Select an option: C
#     Enter amount of withdraw:{User input}
#
#     Select an option: E
#     Thank you for using our service!
# ```

# %% [markdown]
# Bonus: Input validation
# ```
#     Select an option: C
#     Enter amount of deposit: Hello!
#     Incorrect Input
# ```
# Bonus: Insufficient Funds
# ```
#     Select an option: C
#     Enter amount of deposit: 150
#     Insufficient Funds
# ```
# Bonus: Set Withdraw Limit
#
# ```
#     Select an option: C
#     Enter amount of withdraw: 150
#     Cannot withdraw more than $100
#
# ```

# %% [markdown]
# # **Your Space**
