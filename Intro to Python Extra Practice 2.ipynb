# %% [markdown]
# # **Intro to Python Extra Practice 2**
# ***If you end up in an infinite loop(printing the same thing over and over), hit the stop button(same as the play button). If that does not work. Refresh the page.***

# %% [markdown]
# ## Exercise 2.1
#
# Print all odd numbers up to 100.

# %% [markdown]
# ## Exercise 2.2
#
# 1. Create a variable `num1` with the value `0`
# 2. Using a loop, change the value of `num1` to `10`
# 3. Then in another loop bring the value of `num1` to `5`
# 4. Print the value of `num1`

# %% [markdown]
# ## Exercise 2.3
#
# 1. Create a variable `num2` with the value `0`
# 2. Create a variable `num3` with the value `100`
# 3. Inside a loop, bring `num2` and `num3` to 50
# 4. Then print both numbers
#
# *Tip: use the `and` operator inside the loop test*

# %% [markdown]
# ## Exercise 2.4
#
# ### Challenge Question
#
# ***Note: The before section of the loop is already given.***
#
# Loop Test: Check if user `input` is the same as `password`.
#
# Loop Body: Ask for user input and store it into the given `input` variable.
#
# After: Print `"Welcome"`

# %%
password = 'pass'
# write your code below
