# %% [markdown]
# # An introduction to Python
#
# ## Session 2:

# %% [markdown]
# ## What are we learning today?
#
# - Variables
# - How to read and store user input
#
# ####GOAL: Understand variables and work with user input

# %% [markdown]
# ## Variables
#
# Variables are used to attach a name to a value.
# In this case  we are attaching the string `'Hello, World'` to `message`
#
# Now the name has no quotes around it, and as I said earlier this means that Python tries to interpret it as something it should do something with. What it does is to look up the name and substitute in the attached value.
# Whenever the name is used, Python will look it up and substitute in the attached value.

# %%
message = 'Hello, world!'
print(message)

# %% [markdown]
# ## Adding variables together
#
# Just like strings, we can add variables together when printing.

# %%
message = 'Hello, '
message2 = 'world!'
print(message + message2)

# %% [markdown]
# ## Exercises 2.1
#
# 1. Store the current day of the week in a string and print it 3 times.

# %% [markdown]
# ## User input

# %% [markdown]
# Example of storing user input and printing it

# %%
message = input('Name: ')
print(message)

# %% [markdown]
# **Cannot** read in a number.

# %%
#This will not work
number = input('Number: ')
print(number + 1)

# %% [markdown]
# # Converting text to integers
#
# Anything enclosed in qoutes, is a string. The `type()` function can be used to identity the data we are working with.

# %%
type('10')

# %% [markdown]
# There is a function called `int()` ― that converts the textual representation of an integer into a genuine integer.

# %%
type(int('10'))

# %% [markdown]
# There is a similar function called `float()` which creates floating point numbers or decimals

# %%
type(float('10.0'))

# %% [markdown]
# ## Exercises 2.2
#
# 1. Input and store a string
# 2. Convert to a `int()`
# 3. Print the number
