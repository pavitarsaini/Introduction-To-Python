# %% [markdown]
# # **Intro to Python Extra Practice 1**

# %% [markdown]
# ## Exercise 1.1
#
# 1. Input and store a number in the variable `num1`
# 2. Input and store a number in the variable `num2`
# 4. Multiply `num1` by `num2`
# 3. Print the sum of both intergers
#
# *Don't forget to convert the user input to a interger using the `int()` function*

# %% [markdown]
# ## Exercise 1.2
#
# 1. Create a variable `num3` with the value `5`
# 2. Multiply `num3` by itself
# 3. Add `10` to it
# 4. Print whether `num3` is less than or equal to 25
#
# *#4 Tip: print(alpha [comparison operator] delta)*

# %% [markdown]
# ## Exercise 1.3
#
# 1. Create a variable `name` which contains your name
# 2. Create a variable `age` which contains your age
# 3. Create a variable `city` which contains your city
# 4. Print `"My name is [name], I am [age] years old, and I live in [city]"`
#
# *#4 Tip: Concatenation*

# %% [markdown]
# ## Exercise 1.4
#
# ### Challenge Question
#
# Calculate your age based on the current year and the year you were born. Then print what your age will be after 5 years.
#
# Example Output: `I will be [age after 5 years] in 5 years.`
